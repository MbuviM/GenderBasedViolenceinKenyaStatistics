# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Reading the database
data = pd.read_csv('main_GBV.csv')
print (data)
# Out:
#    id  Counties  Population  GBV_Cases(%)  Survivors  Perpetrators  Total
# 0   1     Narok      850920          0.08         32             8     40
# 1   2  Kakamega     1660651          0.16         62            15     78
# 2   3    Migori      917170          0.09         34             9     43
# 3   4      Meru     1356301          0.13         51            13     64
# 4   5   Nairobi     3138369          0.30        118            30    148
# 5   6    Nakuru     1603325          0.15         61            15     75
# 6   7    Kilifi     1109735          0.10         42            10     52

# %%
# Scatter the plot
sns.lineplot(x='Counties' , y='GBV_Cases(%)', data=data)
# Out:
# <AxesSubplot:xlabel='Counties', ylabel='GBV_Cases(%)'>

# %%
# Adding a title to the plot
plt.title('GBV cases per county')
# Out:
# Text(0.5, 1.0, 'GBV cases per county')

# %%
# Setting the x and y labels
plt.xlabel('Counties')
plt.ylabel('GBV_Cases_Percentage')

# Show plot
plt.show()
